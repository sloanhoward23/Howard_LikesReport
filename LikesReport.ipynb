# %% [markdown]
# # Likes Report Assignment
# by Sloan Howard using Sloan Howard's data
#
#
# This report was created to analyze how often I like certain Instagram accounts. I ask this question because I want to see what interests me most on Instagram, I find looking at my own statistics fascinating.
#
# I accessed my own data through Instagram request information section, then I downloaded the file to my desktop.
#
# As a starting point, I needed to use the json and pandas libraries for Python 3.

# %%
import json
import pandas as pd

# %% [markdown]
# The code below shows me loading the data into the kernel.

# %%
with open(r'C:\Users\ADMIN\Desktop\sloanhoward23_20210209\likes\liked_posts.json') as s:
    mylikes = json.load(s)

# %% [markdown]
# "mylikes" is the variable I set for the file.

# %%
mylikes.keys()
# Out:
# dict_keys(['likes_media_likes'])

# %% [markdown]
# This line of code helps me determine how the "media_likes" data is structured.

# %%
type(mylikes['likes_media_likes'])
# Out:
# list

# %%
mylikes['likes_media_likes'][0]
# Out:
# {'title': 'paigeeschert',
#  'media_list_data': [],
#  'string_list_data': [{'href': '',
#    'value': 'ð\x9f\x91\x8d',
#    'timestamp': 1612926021}]}

# %%
type(mylikes['likes_media_likes'][0])
# Out:
# dict

# %% [markdown]
# determines that "title" is the username of an instagram account

# %%
mylikes['likes_media_likes'][0]['title']
# Out:
# 'paigeeschert'

# %%
mylikes['likes_media_likes'][0]['string_list_data'][0]['timestamp']
# Out:
# 1612926021

# %% [markdown]
# This line of code sets "title" as accounts and gives me a list of my last 10 recent likes.

# %%
accounts = [x['title'] for x in mylikes['likes_media_likes']]
accounts[:10]
# Out:
# ['paigeeschert',
#  'marissa.lovee',
#  'meganngross',
#  'guyschmidty',
#  'trailblazers',
#  'slamkicks',
#  'baileigh_susak',
#  'alexadaviss11',
#  'cjrich_',
#  'gtrentjr']

# %%
timestamp = [x['string_list_data'][0]['timestamp'] for x in mylikes['likes_media_likes']]
timestamp[:10]
# Out:
# [1612926021,
#  1612863083,
#  1612743431,
#  1612663942,
#  1612574018,
#  1612574010,
#  1612563436,
#  1612563383,
#  1612563270,
#  1612537838]

# %% [markdown]
# Shows the amount of Instagram posts that I have given a like since the creation of my account.

# %%
print(len(accounts), len(timestamp))
# Out:
# 4194 4194

# %%
mylikes_df = pd.DataFrame({'accounts': accounts, 'timestamp': timestamp})
mylikes_df.head()
# Out:
#         accounts   timestamp
# 0   paigeeschert  1612926021
# 1  marissa.lovee  1612863083
# 2    meganngross  1612743431
# 3    guyschmidty  1612663942
# 4   trailblazers  1612574018

# %%
count_mylikes = mylikes_df.groupby('accounts').count()
count_mylikes.head()
# Out:
#               timestamp
# accounts
# 216.superman          3
# 24k.dayday            1
# 3k.joe                2
# 4amnori               1
# 614badboy_            5

# %% [markdown]
# The list below shows my top 5 most liked accounts since I've had my Instagram.

# %%
count_mylikes.sort_values('timestamp' ,ascending=False).head()
# Out:
#                timestamp
# accounts
# champagnepapi        272
# gabbtyler            188
# kingjames            168
# erruck14             161
# taylarooney_         149

# %% [markdown]
# Here I am implementing matplotlib and pyplot so I can graph these statistics.

# %%
from matplotlib import pyplot as plt

# %% [markdown]
# Also below are the same statistics from the list above, but shown in a bar graph and a pie graph.

# %%
sortcount = count_mylikes.sort_values('timestamp' ,ascending=False)
labels = sortcount['timestamp'].keys()
vals = sortcount['timestamp']
width = .75

fig, ax = plt.subplots(figsize=(10, 10), dpi= 80, facecolor='w', edgecolor='k')
ax.bar(labels, vals, width)
ax.set_ylabel('Likes')
plt.xticks(rotation=90, fontsize = 'small')
plt.show()

# %%
fig2, ax2 = plt.subplots()
ax2.pie(vals, labels = labels)
ax2.axis('equal')
plt.show()

# %% [markdown]
# # In Conclusion
#
# From examining the data above I was able to figure out whose Instagram posts I liked the most over my time using the social media app. I was also able to find out what posts I most recently liked as well. The results that I found were not surprising and confirmed what I thought these statistics would come out to be. I am a huge LeBron James and Drake fan, so when I saw both of their accounts in my top 5 liked all time I was not shocked. I have been following them since I created my account so it makes sense that they are up there. Following those two accounts are people who I have known since I was in middle school. I was in middle school when I created my account so this also was not surprising when I saw some of my first followers in the top 5. The bar and pie graphs also show some of my close friends that I have known and followed for a while now.
